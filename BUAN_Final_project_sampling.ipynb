# %% [markdown]
# <a href="https://colab.research.google.com/github/lucas-berth/BUAN405-Final-Project/blob/main/BUAN_Final_project_sampling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
train_data = pd.read_parquet('/content/drive/MyDrive/train.parquet')

# %%
print("Memory usage of Test data = {:.2f} GB".format(train_data.memory_usage().sum()/1024/1024/1024))
# Out:
# Memory usage of Test data = 2.53 GB

# %%
train_data
# Out:
#                                                customer_ID         S_2  \
# 0        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-03-09
# 1        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-04-07
# 2        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-05-28
# 3        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-06-13
# 4        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-07-16
# ...                                                    ...         ...
# 5531446  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...  2017-11-05
# 5531447  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...  2017-12-23
# 5531448  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...  2018-01-06
# 5531449  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...  2018-02-06
# 5531450  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...  2018-03-14
#
#               P_2  D_39       B_1       B_2       R_1       S_3  D_41  \
# ...

# %%
train_sample = train_data.sample(frac = 0.3, random_state = 1)

# %%
train_sample.shape[0]
# Out:
# 1659435

# %%
#train_sample.to_csv('//content/drive/MyDrive/train_sample.csv') -- already in csv on disk

# %%
test_data = pd.read_parquet('/content/drive/MyDrive/test.parquet')

# %%
test_data
# Out:
#                                                 customer_ID         S_2  \
# 0         00000469ba478561f23a92a868bd366de6f6527a684c9a...  2019-02-19
# 1         00000469ba478561f23a92a868bd366de6f6527a684c9a...  2019-03-25
# 2         00000469ba478561f23a92a868bd366de6f6527a684c9a...  2019-04-25
# 3         00000469ba478561f23a92a868bd366de6f6527a684c9a...  2019-05-20
# 4         00000469ba478561f23a92a868bd366de6f6527a684c9a...  2019-06-15
# ...                                                     ...         ...
# 11363757  fffffa7cf7e453e1acc6a1426475d5cb9400859f82ff61...  2018-12-19
# 11363758  fffffa7cf7e453e1acc6a1426475d5cb9400859f82ff61...  2019-01-19
# 11363759  fffffa7cf7e453e1acc6a1426475d5cb9400859f82ff61...  2019-02-17
# 11363760  fffffa7cf7e453e1acc6a1426475d5cb9400859f82ff61...  2019-03-19
# 11363761  fffffa7cf7e453e1acc6a1426475d5cb9400859f82ff61...  2019-04-18
#
#                P_2  D_39       B_1       B_2  R_1       S_3  D_41       B_3  \
# ...

# %%
test_sample = test_data.sample(frac = 0.3, random_state = 1)

# %%
#test_sample.to_csv('/content/drive/MyDrive/test.csv') -- already in csv on disk

# %%
#both sample files saved to onedrive. the training set is about 2GB and the test set is 3.5GB

# %%
test_sample.shape[0]
# Out:
# 3409129
